# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

hospital_df = pd.read_csv('../downloads/normalizacion/hospital.csv', delimiter=',')
hospital_activity_df = pd.read_csv('../downloads/normalizacion/hospital_activity.csv', delimiter=';')
hospital_municipality_df = pd.read_csv('../downloads/normalizacion/hospital_municipality.csv', delimiter=';')
hospital_resources_df = pd.read_csv('../downloads/normalizacion/hospital_resources.csv', delimiter=';')
municipality_df = pd.read_csv('../downloads/normalizacion/municipality.csv', delimiter=',')
municipality_demographics_df = pd.read_csv('../downloads/normalizacion/municipality_demographics.csv', delimiter=',')

print('Hospitales:')
display(hospital_df.head())
print('Actividad hospitalaria:')
display(hospital_activity_df.head())
print('Hospital-Municipio:')
display(hospital_municipality_df.head())
print('Recursos hospitalarios:')
display(hospital_resources_df.head())
print('Municipios:')
display(municipality_df.head())
print('Demografía municipios:')
display(municipality_demographics_df.head())

# Filtro solicitado sobre hospital_municipality_df
exclude_hospital_id = 'hospital_central_de_la_defensa_gomez_ulla'
exclude_municipality_names = ['Moratalaz', 'Vicálvaro y Retiro', 'Braojos de la Sierra', 'nan']

# Convertir municipality_id a string para evitar problemas de comparación
hospital_municipality_df['municipality_id'] = hospital_municipality_df['municipality_id'].astype(str)

# Filtrar los municipality_id nulos y vacíos
hospital_municipality_df = hospital_municipality_df[hospital_municipality_df['municipality_id'].notnull() & (hospital_municipality_df['municipality_id'] != '')]

# Filtrar por municipality_id
hospital_municipality_df = hospital_municipality_df[~hospital_municipality_df['municipality_id'].isin(exclude_municipality_names)]

# Filtrar por hospital_id
hospital_municipality_df = hospital_municipality_df[hospital_municipality_df['hospital_id'] != exclude_hospital_id]

hospital_resources_2022 = hospital_resources_df[hospital_resources_df['year'].astype(str) == '2022'].copy()
hospital_resources_2022['hospital_id'] = hospital_resources_2022['hospital_id'].astype(str)

hospital_activity_2022 = hospital_activity_df[hospital_activity_df['year'].astype(str) == '2022'].copy()
hospital_activity_2022['hospital_id'] = hospital_activity_2022['hospital_id'].astype(str)

municipality_demographics_2022 = municipality_demographics_df[municipality_demographics_df['year'].astype(str) == '2022'].copy()
municipality_demographics_2022['id_secondary_municipality'] = municipality_demographics_2022['id_secondary_municipality'].astype(str)

# === CÁLCULO DEL NIVEL DE SERVICIO DE HOSPITALES ===

print("\n=== ANÁLISIS DEL NIVEL DE SERVICIO HOSPITALARIO ===\n")

# 1. PREPARAR DATOS DE RECURSOS POR HOSPITAL
hospital_resources_pivot = hospital_resources_2022.pivot_table(
    index='hospital_id',
    columns='type_resources',
    values='total',
    fill_value=0
).reset_index()

print('Recursos hospitalarios por hospital (formato pivote):')
display(hospital_resources_pivot.head())

# 2. PREPARAR DATOS DE ACTIVIDAD POR HOSPITAL
hospital_activity_pivot = hospital_activity_2022.pivot_table(
    index='hospital_id',
    columns='type_activity',
    values='total',
    fill_value=0
).reset_index()

print('\nActividad hospitalaria por hospital (formato pivote):')
display(hospital_activity_pivot.head())

# 3. UNIR RECURSOS Y ACTIVIDAD POR HOSPITAL
hospital_service_df = hospital_resources_pivot.merge(hospital_activity_pivot, on='hospital_id', how='outer')

# 4. CALCULAR INDICADORES DE NIVEL DE SERVICIO

# 4.1 Tasa de ocupación de camas (días de hospitalización / (camas * 365))
if 'Camas instaladas' in hospital_service_df.columns and 'Total ingresos' in hospital_service_df.columns and 'Estancia media global' in hospital_service_df.columns:
    hospital_service_df['dias_hospitalizacion'] = hospital_service_df['Total ingresos'] * hospital_service_df['Estancia media global']
    hospital_service_df['capacidad_anual_camas'] = hospital_service_df['Camas instaladas'] * 365
    hospital_service_df['tasa_ocupacion_camas'] = np.where(
        hospital_service_df['capacidad_anual_camas'] > 0,
        hospital_service_df['dias_hospitalizacion'] / hospital_service_df['capacidad_anual_camas'],
        0
    )

# 4.2 Eficiencia en urgencias (% de ingresos desde urgencias)
if 'Urgencias totales' in hospital_service_df.columns and 'Total ingresos' in hospital_service_df.columns:
    hospital_service_df['tasa_ingreso_urgencias'] = np.where(
        hospital_service_df['Urgencias totales'] > 0,
        hospital_service_df['Total ingresos'] / hospital_service_df['Urgencias totales'],
        0
    )

# 4.3 Eficiencia de ingresos urgentes vs programados
if 'Ingresos urgentes' in hospital_service_df.columns and 'Ingresos programados' in hospital_service_df.columns:
    hospital_service_df['total_ingresos_calculado'] = hospital_service_df['Ingresos urgentes'] + hospital_service_df['Ingresos programados']
    hospital_service_df['ratio_urgentes_programados'] = np.where(
        hospital_service_df['Ingresos programados'] > 0,
        hospital_service_df['Ingresos urgentes'] / hospital_service_df['Ingresos programados'],
        0
    )

# 4.4 Productividad de camas (ingresos por cama)
if 'Total ingresos' in hospital_service_df.columns and 'Camas instaladas' in hospital_service_df.columns:
    hospital_service_df['productividad_camas'] = np.where(
        hospital_service_df['Camas instaladas'] > 0,
        hospital_service_df['Total ingresos'] / hospital_service_df['Camas instaladas'],
        0
    )

# 4.5 Eficiencia de estancia (menor estancia = más eficiente, pero normalizado)
if 'Estancia media global' in hospital_service_df.columns:
    hospital_service_df['eficiencia_estancia'] = np.where(
        hospital_service_df['Estancia media global'] > 0,
        1 / hospital_service_df['Estancia media global'],  # Invertir para que menor estancia = mayor eficiencia
        0
    )

# 5. CALCULAR ÍNDICE COMPUESTO DE NIVEL DE SERVICIO

# Actualizar indicadores disponibles
service_indicators = ['tasa_ocupacion_camas', 'tasa_ingreso_urgencias', 'ratio_urgentes_programados',
                     'productividad_camas', 'eficiencia_estancia']

# Crear copia para normalización
hospital_service_normalized = hospital_service_df.copy()

for indicator in service_indicators:
    if indicator in hospital_service_normalized.columns:
        # Usar percentiles para normalizar (0-100)
        hospital_service_normalized[f'{indicator}_percentile'] = hospital_service_normalized[indicator].rank(pct=True) * 100

        # Para tasa de ocupación, el óptimo está cerca del 80-85%, no al máximo
        if indicator == 'tasa_ocupacion_camas':
            # Penalizar ocupaciones muy bajas (<50%) y muy altas (>95%)
            hospital_service_normalized[f'{indicator}_score'] = np.where(
                hospital_service_normalized[indicator] < 0.5,
                hospital_service_normalized[indicator] * 2 * 100,  # Escala 0-50 para <50%
                np.where(
                    hospital_service_normalized[indicator] > 0.95,
                    100 - (hospital_service_normalized[indicator] - 0.95) * 1000,  # Penalizar >95%
                    100  # Óptimo entre 50-95%
                )
            )
        else:
            hospital_service_normalized[f'{indicator}_score'] = hospital_service_normalized[f'{indicator}_percentile']

# Calcular índice compuesto de nivel de servicio (promedio de scores disponibles)
score_columns = [col for col in hospital_service_normalized.columns if col.endswith('_score')]
if score_columns:
    hospital_service_normalized['nivel_servicio_score'] = hospital_service_normalized[score_columns].mean(axis=1, skipna=True)
else:
    hospital_service_normalized['nivel_servicio_score'] = 0

# 6. AGREGAR INFORMACIÓN DE MUNICIPIO Y NOMBRES DESCRIPTIVOS (SOLO HOSPITALES CON MUNICIPIO)
hospital_service_final = hospital_service_normalized.merge(
    hospital_municipality_df[['hospital_id', 'municipality_id']],
    on='hospital_id',
    how='inner'  # Cambio a INNER JOIN - solo hospitales con municipio asignado
)

# 6.1 Agregar nombres de hospitales
hospital_df['id'] = hospital_df['id'].astype(str)
hospital_service_final = hospital_service_final.merge(
    hospital_df[['id', 'name']].rename(columns={'id': 'hospital_id', 'name': 'hospital_name'}),
    on='hospital_id',
    how='inner'  # INNER JOIN para asegurar que tenemos nombres
)

# 6.2 Agregar nombres de municipios
municipality_df['id'] = municipality_df['id'].astype(str)
hospital_service_final = hospital_service_final.merge(
    municipality_df[['id', 'name']].rename(columns={'id': 'municipality_id', 'name': 'municipality_name'}),
    on='municipality_id',
    how='inner'  # INNER JOIN para asegurar que tenemos nombres de municipio
)

# 7. MOSTRAR RESULTADOS CON NOMBRES DESCRIPTIVOS
print('\n=== INDICADORES DE NIVEL DE SERVICIO POR HOSPITAL ===')
service_columns = ['hospital_id', 'hospital_name', 'municipality_id', 'municipality_name'] + [col for col in hospital_service_final.columns if 'tasa_' in col or 'ratio_' in col or 'productividad_' in col or 'eficiencia_' in col or 'nivel_servicio' in col]
service_results = hospital_service_final[service_columns].round(4)
display(service_results.head(10))

print('\n=== TOP 10 HOSPITALES POR NIVEL DE SERVICIO ===')
# Usar solo columnas que existen incluyendo nombres
top_columns = ['hospital_id', 'hospital_name', 'municipality_id', 'municipality_name', 'nivel_servicio_score']
if 'tasa_ocupacion_camas' in hospital_service_final.columns:
    top_columns.append('tasa_ocupacion_camas')
if 'tasa_ingreso_urgencias' in hospital_service_final.columns:
    top_columns.append('tasa_ingreso_urgencias')
if 'productividad_camas' in hospital_service_final.columns:
    top_columns.append('productividad_camas')

top_hospitals = hospital_service_final.nlargest(10, 'nivel_servicio_score')[top_columns]
display(top_hospitals)

print('\n=== ESTADÍSTICAS GENERALES DE NIVEL DE SERVICIO ===')
print(f"Nivel de servicio promedio: {hospital_service_final['nivel_servicio_score'].mean():.2f}")
print(f"Desviación estándar: {hospital_service_final['nivel_servicio_score'].std():.2f}")
print(f"Nivel de servicio máximo: {hospital_service_final['nivel_servicio_score'].max():.2f}")
print(f"Nivel de servicio mínimo: {hospital_service_final['nivel_servicio_score'].min():.2f}")

# 8. ANÁLISIS POR MUNICIPIO CON NOMBRES DESCRIPTIVOS
print('\n=== NIVEL DE SERVICIO HOSPITALARIO POR MUNICIPIO ===')

# Definir columnas disponibles para agregación
agg_dict = {'nivel_servicio_score': 'mean', 'hospital_id': 'count', 'municipality_name': 'first'}

if 'tasa_ocupacion_camas' in hospital_service_final.columns:
    agg_dict['tasa_ocupacion_camas'] = 'mean'
if 'tasa_ingreso_urgencias' in hospital_service_final.columns:
    agg_dict['tasa_ingreso_urgencias'] = 'mean'
if 'productividad_camas' in hospital_service_final.columns:
    agg_dict['productividad_camas'] = 'mean'
if 'eficiencia_estancia' in hospital_service_final.columns:
    agg_dict['eficiencia_estancia'] = 'mean'
if 'Camas instaladas' in hospital_service_final.columns:
    agg_dict['Camas instaladas'] = 'sum'
if 'Total ingresos' in hospital_service_final.columns:
    agg_dict['Total ingresos'] = 'sum'

# Agrupar por municipio y calcular promedios
municipio_service = hospital_service_final.groupby('municipality_id').agg(agg_dict).round(4)

municipio_service = municipio_service.rename(columns={'hospital_id': 'num_hospitales'})
municipio_service = municipio_service.sort_values('nivel_servicio_score', ascending=False)

# Reorganizar columnas para mostrar nombre del municipio primero
if 'municipality_name' in municipio_service.columns:
    cols = ['municipality_name'] + [col for col in municipio_service.columns if col != 'municipality_name']
    municipio_service = municipio_service[cols]

display(municipio_service.head(10))

# 9. MOSTRAR MEJORES Y PEORES HOSPITALES CON DETALLES
print('\n=== 5 MEJORES HOSPITALES ===')
mejores_hospitales = hospital_service_final.nlargest(5, 'nivel_servicio_score')[
    ['hospital_name', 'municipality_name', 'nivel_servicio_score',
     'tasa_ocupacion_camas', 'tasa_ingreso_urgencias', 'productividad_camas', 'eficiencia_estancia']
].round(4)
display(mejores_hospitales)

print('\n=== 5 HOSPITALES CON MENOR NIVEL DE SERVICIO ===')
peores_hospitales = hospital_service_final.nsmallest(5, 'nivel_servicio_score')[
    ['hospital_name', 'municipality_name', 'nivel_servicio_score',
     'tasa_ocupacion_camas', 'tasa_ingreso_urgencias', 'productividad_camas', 'eficiencia_estancia']
].round(4)
display(peores_hospitales)

# Guardar resultado final para análisis posterior
hospitalizacion_poblacion_df = hospital_service_final.copy()

# 10. GRÁFICAS Y ANÁLISIS VISUAL
print('\n=== ANÁLISIS VISUAL DEL NIVEL DE SERVICIO ===')

# Configurar estilo de matplotlib
plt.style.use('default')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 10

# 10.1 GRÁFICA DE DISPERSIÓN: Ocupación vs Productividad
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 12))

# Gráfica 1: Tasa de ocupación vs Productividad de camas
if 'tasa_ocupacion_camas' in hospital_service_final.columns and 'productividad_camas' in hospital_service_final.columns:
    scatter = ax1.scatter(hospital_service_final['tasa_ocupacion_camas'],
                         hospital_service_final['productividad_camas'],
                         c=hospital_service_final['nivel_servicio_score'],
                         cmap='viridis', alpha=0.7, s=60)
    ax1.set_xlabel('Tasa de Ocupación de Camas')
    ax1.set_ylabel('Productividad de Camas (ingresos/cama)')
    ax1.set_title('Ocupación vs Productividad de Camas')
    ax1.grid(True, alpha=0.3)
    plt.colorbar(scatter, ax=ax1, label='Nivel de Servicio')

# Gráfica 2: Eficiencia de estancia vs Nivel de servicio
if 'eficiencia_estancia' in hospital_service_final.columns:
    ax2.scatter(hospital_service_final['eficiencia_estancia'],
               hospital_service_final['nivel_servicio_score'],
               alpha=0.7, s=60, color='orange')
    ax2.set_xlabel('Eficiencia de Estancia (1/días)')
    ax2.set_ylabel('Nivel de Servicio')
    ax2.set_title('Eficiencia de Estancia vs Nivel de Servicio')
    ax2.grid(True, alpha=0.3)

# Gráfica 3: Distribución del nivel de servicio
ax3.hist(hospital_service_final['nivel_servicio_score'], bins=20, alpha=0.7, color='skyblue', edgecolor='black')
ax3.axvline(hospital_service_final['nivel_servicio_score'].mean(), color='red', linestyle='--', linewidth=2, label=f'Media: {hospital_service_final["nivel_servicio_score"].mean():.1f}')
ax3.set_xlabel('Nivel de Servicio')
ax3.set_ylabel('Frecuencia')
ax3.set_title('Distribución del Nivel de Servicio')
ax3.legend()
ax3.grid(True, alpha=0.3)

# Gráfica 4: Top 10 municipios por nivel de servicio
top_municipios = municipio_service.head(10)
y_pos = range(len(top_municipios))
bars = ax4.barh(y_pos, top_municipios['nivel_servicio_score'], color='lightgreen', alpha=0.8)
ax4.set_yticks(y_pos)
ax4.set_yticklabels([name[:20] + '...' if len(name) > 20 else name for name in top_municipios['municipality_name']], fontsize=8)
ax4.set_xlabel('Nivel de Servicio Promedio')
ax4.set_title('Top 10 Municipios por Nivel de Servicio')
ax4.grid(True, alpha=0.3, axis='x')

# Agregar valores en las barras
for i, bar in enumerate(bars):
    width = bar.get_width()
    ax4.text(width + 0.5, bar.get_y() + bar.get_height()/2, f'{width:.1f}',
             ha='left', va='center', fontsize=8)

plt.tight_layout()
plt.show()

# 10.2 ESTADÍSTICAS DE LA COMUNIDAD DE MADRID
print('\n=== ESTADÍSTICAS DE LA COMUNIDAD DE MADRID ===')

# Estadísticas generales
total_hospitales = len(hospital_service_final)
media_servicio = hospital_service_final['nivel_servicio_score'].mean()
mediana_servicio = hospital_service_final['nivel_servicio_score'].median()
std_servicio = hospital_service_final['nivel_servicio_score'].std()

print(f"📊 RESUMEN GENERAL:")
print(f"   • Total de hospitales analizados: {total_hospitales}")
print(f"   • Nivel de servicio promedio: {media_servicio:.2f}")
print(f"   • Mediana del nivel de servicio: {mediana_servicio:.2f}")
print(f"   • Desviación estándar: {std_servicio:.2f}")

# Percentiles
p25 = hospital_service_final['nivel_servicio_score'].quantile(0.25)
p75 = hospital_service_final['nivel_servicio_score'].quantile(0.75)
print(f"   • Percentil 25: {p25:.2f}")
print(f"   • Percentil 75: {p75:.2f}")

# Clasificación de hospitales por nivel de servicio
excelente = (hospital_service_final['nivel_servicio_score'] >= 80).sum()
bueno = ((hospital_service_final['nivel_servicio_score'] >= 60) & (hospital_service_final['nivel_servicio_score'] < 80)).sum()
regular = ((hospital_service_final['nivel_servicio_score'] >= 40) & (hospital_service_final['nivel_servicio_score'] < 60)).sum()
deficiente = (hospital_service_final['nivel_servicio_score'] < 40).sum()

print(f"\n🏥 CLASIFICACIÓN DE HOSPITALES:")
print(f"   • Excelente (≥80): {excelente} hospitales ({excelente/total_hospitales*100:.1f}%)")
print(f"   • Bueno (60-79): {bueno} hospitales ({bueno/total_hospitales*100:.1f}%)")
print(f"   • Regular (40-59): {regular} hospitales ({regular/total_hospitales*100:.1f}%)")
print(f"   • Deficiente (<40): {deficiente} hospitales ({deficiente/total_hospitales*100:.1f}%)")

# Estadísticas por indicador
print(f"\n📈 PROMEDIOS POR INDICADOR:")
if 'tasa_ocupacion_camas' in hospital_service_final.columns:
    print(f"   • Tasa de ocupación promedio: {hospital_service_final['tasa_ocupacion_camas'].mean():.1%}")
if 'tasa_ingreso_urgencias' in hospital_service_final.columns:
    print(f"   • Tasa de ingreso urgencias promedio: {hospital_service_final['tasa_ingreso_urgencias'].mean():.3f}")
if 'productividad_camas' in hospital_service_final.columns:
    print(f"   • Productividad de camas promedio: {hospital_service_final['productividad_camas'].mean():.1f} ingresos/cama/año")
if 'eficiencia_estancia' in hospital_service_final.columns:
    print(f"   • Eficiencia de estancia promedio: {hospital_service_final['eficiencia_estancia'].mean():.3f}")

# 10.3 ANÁLISIS POR MUNICIPIOS MÁS GRANDES
print(f"\n🏙️ ANÁLISIS DE MUNICIPIOS PRINCIPALES:")

# Municipios con más hospitales
municipios_grandes = municipio_service[municipio_service['num_hospitales'] >= 3].sort_values('nivel_servicio_score', ascending=False)

if len(municipios_grandes) > 0:
    print("Municipios con 3+ hospitales (ordenados por nivel de servicio):")
    for idx, row in municipios_grandes.head(5).iterrows():
        print(f"   • {row['municipality_name']}: {row['nivel_servicio_score']:.1f} puntos ({int(row['num_hospitales'])} hospitales)")

# 10.4 MAPA DE CALOR DE CORRELACIONES
print('\n=== CORRELACIONES ENTRE INDICADORES ===')

# Seleccionar solo las columnas numéricas de interés
correlation_cols = ['nivel_servicio_score']
if 'tasa_ocupacion_camas' in hospital_service_final.columns:
    correlation_cols.append('tasa_ocupacion_camas')
if 'tasa_ingreso_urgencias' in hospital_service_final.columns:
    correlation_cols.append('tasa_ingreso_urgencias')
if 'productividad_camas' in hospital_service_final.columns:
    correlation_cols.append('productividad_camas')
if 'eficiencia_estancia' in hospital_service_final.columns:
    correlation_cols.append('eficiencia_estancia')
if 'Total ingresos' in hospital_service_final.columns:
    correlation_cols.append('Total ingresos')

# Calcular correlaciones
corr_matrix = hospital_service_final[correlation_cols].corr()

# Mostrar gráfica de correlaciones
plt.figure(figsize=(10, 8))
im = plt.imshow(corr_matrix, cmap='coolwarm', aspect='auto', vmin=-1, vmax=1)
plt.colorbar(im, label='Correlación')
plt.xticks(range(len(correlation_cols)), correlation_cols, rotation=45, ha='right')
plt.yticks(range(len(correlation_cols)), correlation_cols)
plt.title('Mapa de Calor - Correlaciones entre Indicadores')

# Agregar valores de correlación en las celdas
for i in range(len(correlation_cols)):
    for j in range(len(correlation_cols)):
        plt.text(j, i, f'{corr_matrix.iloc[i, j]:.2f}',
                ha='center', va='center', color='black' if abs(corr_matrix.iloc[i, j]) < 0.5 else 'white')

plt.tight_layout()
plt.show()
# Out:
# Hospitales:
#        id                                         name_large  \
# 0  280724  Hospital Centro Sanitario de Vida y Esperanza....
# 1  CH0001  Fremap Hospital y Centro de Rehabilitación de ...
# 2  CH0004  Centro San Juan de Dios. Avenida de San Juan d...
# 3  CH0006  Fuensanta S.l. (Clínica Fuensanta). Calle de A...
# 4  CH0008  Clínica La Luz, S.l.. Calle del General Rodrig...
#
#                                                 name  id_municipality   utm_x  \
# 0      HOSPITAL CENTRO SANITARIO DE VIDA Y ESPERANZA            28079  436745
# 1  FREMAP HOSPITAL Y CENTRO DE REHABILITACIÓN DE ...            28080  427799
# 2                            CENTRO SAN JUAN DE DIOS            28040  447682
# 3                 FUENSANTA S.L. (CLINICA FUENSANTA)            28079  445713
# 4                               CLINICA LA LUZ, S.L.            28079  439451
#
#      utm_y                                                tag  \
# ...
